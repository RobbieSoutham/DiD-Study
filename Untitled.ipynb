# %%
# Import core components
import pandas as pd
from did_study.helpers.config import StudyConfig
from did_study.study import DidStudy
from did_study.helpers.defaults import DEFAULT_MAPPING
# Out:
# Error importing in API mode: ImportError('On Windows, cffi mode "ANY" is only "ABI".')
# Trying to import in ABI mode.

# %%
import numpy as np
import matplotlib.pyplot as plt

s = pd.to_numeric(raw_df["eor_capacity"], errors="coerce").dropna()
s = s[s > 0]  # doses are positive

bins = np.linspace(s.min(), s.max(), 40)
plt.figure()
plt.hist(s, bins=bins)
plt.xscale("log")
plt.xlabel("EOR capacity (absolute units)")
plt.ylabel("Count")
plt.title("Distribution of EOR capacity (log scale)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 s = pd.to_numeric(raw_df["eor_capacity"], errors="coerce").dropna()
#       5 s = s[s > 0]  # doses are positive
#       7 bins = np.linspace(s.min(), s.max(), 40)
#
# NameError: name 'raw_df' is not defined

# %%
raw_df = pd.read_csv("ds_no_prep.csv")

raw_df['eor_capacity'].describe()

# %%
import numpy as np
# Build a simple synthetic dataset (two countries × two sectors × six years)
raw_df = pd.read_csv("ds_no_prep.csv")

# Specify covariates
covariates = [
    'Demand_heat', #'Demand_electricity',  #'Demand_nuclear',
    'Demand_renewables_and_waste', #'Supply_nuclear',
    'energy_demand_fossil_fuels', 'CPI_growth',
    'GDP_per_capita_PPP', 'renewable_to_fossil_supply_ratio', 'nuclear_share_supply'
]

# Create a StudyConfig; note outcome_mode='total' collapses to country level
cfg = StudyConfig(
    df=raw_df,
    outcome_mode='direct',
    supdem_mode='direct',
    mapping=DEFAULT_MAPPING,
    unit_cols=('Country','CCUS_sector'),
    year_col='Year',
    outcome_col='Emissions',
    emissions_sector_col='emissions_sector',
    capacity_col='eor_capacity',
    sector_col='Sector',
    covariates=covariates,
    differenced=False,
    use_log_outcome=True,
    use_lag_levels_in_diff=False,
    min_pre=3,
    min_post=5,
    n_bins=3,
    #dose_bins=[0.01, 0.3, 1.5, np.inf],
    treat_threshold=0.0,
    pre=3,
    post=5,
    use_wcb=True,           # disable bootstrap for speed (set True to enable)
    wcb_B=9999,
    wcb_weights='auto',
    min_cluster_support=2,
    #optimise_ds=False
)

main_cfg = StudyConfig(
    df=raw_df,
    outcome_mode='direct',
    supdem_mode='direct',
    mapping=DEFAULT_MAPPING,
    unit_cols=('Country','CCUS_sector'),
    year_col='Year',
    outcome_col='Emissions',
    emissions_sector_col='emissions_sector',
    capacity_col='eor_capacity',
    sector_col='Sector',
    covariates=covariates,
    differenced=False,
    use_log_outcome=True,
    use_lag_levels_in_diff=False,
    min_pre=4,
    min_post=2,
    n_bins=3,
    #dose_bins=[0.01, 0.3, 1.5, np.inf],
    treat_threshold=0.0,
    pre=5,
    post=8,
    use_wcb=True,           # disable bootstrap for speed (set True to enable)
    wcb_B=9999,
    wcb_weights='auto',
    min_cluster_support=2,
    #optimise_ds=False
)

# After you've run your study:
results = DidStudy(cfg).run()

# Remidner Sector-level outcomes have 2-3x lower variance than country aggregates,
# Out:
# [prepare][bins] absorbing (n_bins_quantile); edges=[0.1, 0.68, 3.0, 10.6]
#   - [0.1, 0.68): units=6, rows=91
#   - [0.68, 3.0): units=3, rows=53
#   - [3.0, 10.6): units=2, rows=29
#   - untreated: units=1, rows=10
# [prepare] Dropped 6 units with insufficient pre/post support.
#   - [0.1, 0.68): dose range=[0.1, 1.3], CV=0.95
#   - [0.68, 3.0): dose range=[1.0, 1.0], CV=0.00
#   - [3.0, 10.6): dose range=[0.0, 3.9], CV=0.49
# [WARNING] nuclear_share_supply changes 0.392 post-treatment (potential bad control)
# === PANEL STATS ===
# Units: 293 | Ever-treated: 7 | Obs: 11736 | Post rows: 92 (0.8%)
# Too guarantee reproducibility, don't forget to set a global random seed **both** via `set.seed()` and
# `dqrng::dqset.seed()`.
# This message is displayed once every 8 hours.
# R callback write-console: In addition:
# R callback write-console: Warning message:
#
# R callback write-console: Please note that the seeding behavior for random number generation for `boottest()` has changed with `fwildclusterboot`
# version 0.13.
#
# It will no longer be possible to exactly reproduce results produced by versions lower than 0.13.
#
# If your prior results were produced under sufficiently many bootstrap iterations, none of your conclusions will change.
# For more details about this change, please read the notes in
# [news.md](https://cran.r-project.org/web/packages/fwildclusterboot/news/news.html).
# This warning is displayed once per session.
# [PY/OLS] Omnibus/analytic
#   formula: log_y ~ C(dose_bin_str, Treatment(reference='untreated')) + Demand_heat + Demand_renewables_and_waste + energy_demand_fossil_fuels + CPI_growth + GDP_per_capita_PPP + renewable_to_fossil_supply_ratio + nuclear_share_supply | Year + unit_id
#   cluster: unit_id
# ----------------------
# [WCB] joint tests failed; returning NaN p-values. Reason: AttributeError("'DataFrame' object has no attribute 'dtype'")
# R callback write-console: Error in A %*% sigma %*% base::t(A) : non-conformable arguments
#
# R callback write-console: In addition:
# R callback write-console: Warning message:
#
# R callback write-console: In (function (data = NA, nrow = 1, ncol = 1, byrow = FALSE, dimnames = NULL)  :
# R callback write-console:
#
# R callback write-console:  data length [113569] is not a sub-multiple or multiple of the number of rows [8]
#
# R callback write-console: Error in A %*% sigma %*% base::t(A) : non-conformable arguments
#
# R callback write-console: In addition:
# R callback write-console: Warning message:
#
# R callback write-console: In (function (data = NA, nrow = 1, ncol = 1, byrow = FALSE, dimnames = NULL)  :
# R callback write-console:
#
# R callback write-console:  data length [113569] is not a sub-multiple or multiple of the number of rows [8]
#
# R callback write-console: Error in A %*% sigma %*% base::t(A) : non-conformable arguments
#
# R callback write-console: In addition:
# R callback write-console: Warning message:
#
# R callback write-console: In (function (data = NA, nrow = 1, ncol = 1, byrow = FALSE, dimnames = NULL)  :
# R callback write-console:
#
# R callback write-console:  data length [113569] is not a sub-multiple or multiple of the number of rows [8]
#
# R callback write-console: Error in A %*% sigma %*% base::t(A) : non-conformable arguments
#
# R callback write-console: In addition:
# R callback write-console: Warning message:
#
# R callback write-console: In (function (data = NA, nrow = 1, ncol = 1, byrow = FALSE, dimnames = NULL)  :
# R callback write-console:
#
# R callback write-console:  data length [113569] is not a sub-multiple or multiple of the number of rows [8]
#
# R callback write-console: Error in A %*% sigma %*% base::t(A) : non-conformable arguments
#
# R callback write-console: In addition:
# R callback write-console: Warning message:
#
# R callback write-console: In (function (data = NA, nrow = 1, ncol = 1, byrow = FALSE, dimnames = NULL)  :
# R callback write-console:
#
# R callback write-console:  data length [113569] is not a sub-multiple or multiple of the number of rows [8]
#
# R callback write-console: Error in A %*% sigma %*% base::t(A) : non-conformable arguments
#
# R callback write-console: In addition:
# R callback write-console: Warning message:
#
# R callback write-console: In (function (data = NA, nrow = 1, ncol = 1, byrow = FALSE, dimnames = NULL)  :
# R callback write-console:
#
# R callback write-console:  data length [113569] is not a sub-multiple or multiple of the number of rows [8]
#
# R callback write-console: Error in A %*% sigma %*% base::t(A) : non-conformable arguments
#
# R callback write-console: In addition:
# R callback write-console: Warning message:
#
# R callback write-console: In (function (data = NA, nrow = 1, ncol = 1, byrow = FALSE, dimnames = NULL)  :
# R callback write-console:
#
# R callback write-console:  data length [113569] is not a sub-multiple or multiple of the number of rows [8]
#
# R callback write-console: Error in A %*% sigma %*% base::t(A) : non-conformable arguments
#
# R callback write-console: In addition:
# R callback write-console: Warning message:
#
# R callback write-console: In (function (data = NA, nrow = 1, ncol = 1, byrow = FALSE, dimnames = NULL)  :
# R callback write-console:
#
# R callback write-console:  data length [113569] is not a sub-multiple or multiple of the number of rows [8]
#
# R callback write-console: Error in A %*% sigma %*% base::t(A) : non-conformable arguments
#
# R callback write-console: In addition:
# R callback write-console: Warning message:
#
# R callback write-console: In (function (data = NA, nrow = 1, ncol = 1, byrow = FALSE, dimnames = NULL)  :
# R callback write-console:
#
# R callback write-console:  data length [113569] is not a sub-multiple or multiple of the number of rows [8]

# %%
from did_study.reporting.summary import print_and_plot_summary, study_printable_from_didstudy
a = study_printable_from_didstudy(results)
print_and_plot_summary(a, make_combo=True)
# Out:
# ==============================================================================
# PANEL STATS
# ==============================================================================
# Units: None | Ever-treated: None | Obs: None | Post rows: None (0.0%)
# Bin edges: [35.52, 41.28, 756.0, 2671.2]
#
# ==============================================================================
# ATT^o (pooled)
# ==============================================================================
# coef = -0.173 (SE 0.106, p 0.104) | 95% CI [-0.382, 0.036] | clusters=295, n=11822
# WCB p = 0.001 — (fwildclusterboot::boottest, two-sided; weights=auto, B=9999)
# MDE (α=0.05, 80% power): 0.2984 (Δlog scale ≈ percentage points; 0.01 ≈ 1 p.p.)
# ==============================================================================
# ATT^o by dose bin
# ==============================================================================
# (no bins)
#
# ==============================================================================
# ATT^o summary table (pooled + bins)
# ==============================================================================
#  group   coef    se     p          95% CI   WCB p
# pooled -0.173 0.106 0.104 [-0.382, 0.036] 0.001**
#
# ==============================================================================
# Event Study (pooled)
# ==============================================================================
# [first rows]
#  event_time      beta       se        p        lo       hi
#          -5  0.014980 0.096994 0.877259 -0.175129 0.205089
#          -4  0.028092 0.100133 0.779056 -0.168168 0.224352
#          -3 -0.004406 0.106223 0.966917 -0.212603 0.203792
#          -2 -0.015144 0.117775 0.897688 -0.245984 0.215696
#           0 -0.043386 0.135478 0.748785 -0.308922 0.222151
#           1 -0.058220 0.132750 0.660973 -0.318411 0.201970
#           2 -0.042856 0.139013 0.757864 -0.315320 0.229609
#           3 -0.187421 0.113096 0.097483 -0.409090 0.034247
# PTA (leads joint = 0) p = 0.826 — Pre-trend: fail to reject H0 at 5%.
# ==============================================================================
# HonestDiD
# ==============================================================================
# [first rows]
#  M=0.00: [-0.330, +0.057] (naive θ̂=-0.135)
#  M=0.25: [-0.567, +0.263] (naive θ̂=-0.135)
#  M=0.50: [-0.812, +0.472] (naive θ̂=-0.135)
#  Summary: bounds include 0 across M-grid (no robust sign).
# ==============================================================================
# Overall Support
# ==============================================================================
# PTA (pre-trends): p = 0.826 → PASS (fail-to-reject is PASS).
#
# ATT^o (pooled):
#   Estimate: -0.1727 (p = 0.104, WCB p = 0.001**)
#   MDE (α=0.05, 80% power): 0.2984
#   |estimate| > MDE: No → Effect may not be robust
#
# WCB omnibus over bins: NA (not computed)
#
# HonestDiD: bounds include 0 across M-grid → no robust sign.

# %%
a

# %%
from did_study.robustness.wcb import wcb_att_pvalue_r
df = results["panel"]
y  = cfg.outcome
covs = results["panel_info"].get("covariates_used", [])
fe = [cfg.year_col] + ([] if y.startswith("d_") else [cfg.unit_cols[0]])
p = wcb_att_pvalue_r(df, outcome=y, regressors=["treated_now"]+covs,
                     fe=fe, cluster=cfg.unit_cols[0], param="treated_now",
                     B=9999, weights="webb", impose_null=True, seed=123)
print("WCB ATT^o p =", p)
from did_study.robustness.wcb import wcb_joint_pvalue_r
# using the same regressors you fit the ES with
pta_p = wcb_joint_pvalue_r(df, outcome=y, regressors=inter_cols+covs,
                           fe=fe, cluster=cfg.unit_cols[0],
                           joint_zero=lead_names,
                           B=9999, weights="webb", impose_null=True, seed=123)
print("PTA WCB p =", pta_p)

# %%
def get_VIF_values(
    df: pd.DataFrame,
    predictors: list,
    min_non_missing: float = 0.50,  # keep cols with ≥50% non-missing
    min_rows: int = 30,             # need rows >> cols
    save_file: str = None
) -> pd.DataFrame:
    X = df[predictors].copy()

    # Screen: coverage & variance
    keep = []
    for c in X.columns:
        s = X[c]
        if s.notna().mean() >= min_non_missing and s.nunique(dropna=True) > 1:
            keep.append(c)
    X = X[keep]

    # Median-impute remaining missings to avoid row wipeout (safer than fillna(0))
    X = X.apply(lambda s: s.fillna(s.median()), axis=0)

    # Bail if not enough data
    if X.shape[1] <= 1 or X.shape[0] < max(min_rows, 2 * X.shape[1]):
        print("[VIF] Skipped: insufficient rows/columns after screening.")
        return pd.DataFrame({"feature": keep, "VIF": np.nan})

    Xc = add_constant(X, has_constant="add")

    rows = []
    for i, col in enumerate(Xc.columns):
        if col == "const":   # do not report VIF for the constant
            continue
        try:
            vif_val = float(variance_inflation_factor(Xc.values, i))
        except Exception:
            vif_val = np.nan
        rows.append({"feature": col, "VIF": vif_val})

    vif_df = (pd.DataFrame(rows)
                .sort_values("VIF", ascending=False)
                .reset_index(drop=True))

    print("\n=== VIF (differenced covariates) ===")
    print(vif_df.head(20).to_string(index=False))

    if save_file:
        try:
            vif_df.to_csv(save_file, index=False)
        except Exception as e:
            print(f"[VIF] Could not save file: {e}")
    return vif_df

# %%
raw_df['a/b'] = ''

# %%
import numpy as np
get_VIF_values(results['att_bins'].used, predictors=d_covs)

# %%
raw_df['eor_capacity'].describe()
