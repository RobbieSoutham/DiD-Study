# %%
# Import core components
import pandas as pd
from did_study.helpers.config import StudyConfig
from did_study.study import DidStudy
from did_study.helpers.defaults import DEFAULT_MAPPING
# Out:
# Error importing in API mode: ImportError('On Windows, cffi mode "ANY" is only "ABI".')
# Trying to import in ABI mode.

# %%
import sys
print(sys.path)
# Out:
# ['C:\\Program Files\\Python313\\python313.zip', 'C:\\Program Files\\Python313\\DLLs', 'C:\\Program Files\\Python313\\Lib', 'C:\\Program Files\\Python313', 'C:\\Users\\rjsou\\Documents\\PhD\\did_study\\venv', '', 'C:\\Users\\rjsou\\Documents\\PhD\\did_study\\venv\\Lib\\site-packages']

# %%
import numpy as np
# Import core components
import pandas as pd
from did_study.helpers.config import StudyConfig
from did_study.study import DidStudy
from did_study.helpers.defaults import DEFAULT_MAPPING
# Build a simple synthetic dataset (two countries × two sectors × six years)
raw_df = pd.read_csv("ds_no_prep.csv")

# Specify covariates
covariates = [
    'Demand_heat', 'Demand_electricity',  'Demand_nuclear',
    'Demand_renewables_and_waste', 'Supply_nuclear',
    'energy_demand_fossil_fuels', 'CPI_growth',
    'GDP_per_capita_PPP', 'renewable_to_fossil_supply_ratio', 'nuclear_share_supply'
]

# Create a StudyConfig; note outcome_mode='total' collapses to country level
cfg = StudyConfig(
    df=raw_df,
    outcome_mode='direct',
    supdem_mode='direct',
    mapping=DEFAULT_MAPPING,
    unit_cols=('Country','CCUS_sector'),
    year_col='Year',
    outcome_col='Emissions',
    emissions_sector_col='emissions_sector',
    capacity_col='eor_capacity',
    sector_col='Sector',
    covariates=covariates,
    differenced=False,
    use_log_outcome=True,
    use_lag_levels_in_diff=False,
    min_pre=3,
    min_post=5,
    n_bins=3,
    #dose_bins=[0.01, 0.3, 1.5, np.inf],
    treat_threshold=0.0,
    pre=3,
    post=5,
    use_wcb=True,           # disable bootstrap for speed (set True to enable)
    wcb_B=9999,
    wcb_weights='auto',
    min_cluster_support=2,
    #optimise_ds=False
)

covariates = [
    'Demand_heat', #'Demand_electricity',  #'Demand_nuclear',
    'Demand_renewables_and_waste', #'Supply_nuclear',
    'energy_demand_fossil_fuels', 'CPI_growth',
    'GDP_per_capita_PPP'#, 'renewable_to_fossil_supply_ratio', #'nuclear_share_supply'
]

main_cfg = StudyConfig(
    df=raw_df,
    outcome_mode='direct',
    supdem_mode='direct',
    mapping=DEFAULT_MAPPING,
    unit_cols=('Country','CCUS_sector'),
    year_col='Year',
    outcome_col='Emissions',
    emissions_sector_col='emissions_sector',
    capacity_col='eor_capacity',
    sector_col='Sector',
    covariates=covariates,
    differenced=False,
    use_log_outcome=True,
    use_lag_levels_in_diff=False,
    min_pre=4,
    min_post=2,
    n_bins=3,
    cluster_col = "unit_id",
    #dose_bins=[0.1, 0.5, 2.0, np.inf],
    treat_threshold=0.0,
    pre=5,
    post=8,
    use_wcb=True,           # disable bootstrap for speed (set True to enable)
    wcb_B=100,
    wcb_weights='auto',
    min_cluster_support=2,
    #optimise_ds=False
)

# After you've run your study:
results = DidStudy(main_cfg).run()

# Remidner Sector-level outcomes have 2-3x lower variance than country aggregates,
# Out:
# [prepare][bins] absorbing (n_bins_quantile); edges=[0.1, 0.68, 3.0, 10.6]
#   - [0.1, 0.68): units=6, rows=91, dose range=[0.1, 9.6], CV=1.26
#   - [0.68, 3): units=3, rows=53, dose range=[0.7, 1.9], CV=0.47
#   - [3, 10.6): units=2, rows=29, dose range=[0.0, 3.9], CV=0.49
# [prepare] Saved covariates scaler -> None
# [prepare] Dropped 4 units with insufficient pre/post support.
#   - [0.1, 0.68): dose range=[0.1, 1.3], CV=0.91
#   - [0.68, 3): dose range=[1.0, 1.3], CV=0.13
#   - [3, 10.6): dose range=[0.0, 3.9], CV=0.49
# === PANEL STATS ===
# Units: 295 | Ever-treated: 9 | Obs: 11822 | Post rows: 98 (0.8%)
# ========================================================================
# [WCB CALL] -> boottest_fixest
# ========================================================================
# Parameters:
#   - outcome: log_y
#   - regressors: ['treated_now', 'Demand_heat', 'Demand_renewables_and_waste', 'energy_demand_fossil_fuels', 'CPI_growth', 'GDP_per_capita_PPP']
#   - fe: ['unit_id', 'Year']
#   - cluster: ['unit_id']
#   - param: treated_now
#   - joint_zero: None
#   - B: 100
#   - type/weights: rademacher
#   - impose_null: True
#   - seed: 123
#   - Formula: log_y ~ treated_now + Demand_heat + Demand_renewables_and_waste + energy_demand_fossil_fuels + CPI_growth + GDP_per_capita_PPP | unit_id + Year
#
# Too guarantee reproducibility, don't forget to set a global
# random seed **both** via `set.seed()` and
# `dqrng::dqset.seed()`.
# This message is displayed once every 8 hours.
# Note: The bootstrap usually performs best when the confidence
# level (here, 0.95 % times the number of replications plus 1 (
# 100 + 1 = 101 ) is an integer.
# R callback write-console: In addition:
# R callback write-console: Warning message:
#
# R callback write-console: Please note that the seeding behavior for random number
# generation for `boottest()` has changed with
# `fwildclusterboot` version 0.13.
#
# It will no longer be possible to exactly reproduce results
# produced by versions lower than 0.13.
#
# If your prior results were produced under sufficiently many
# bootstrap iterations, none of your conclusions will change.
# For more details about this change, please read the notes in
# [news.md](https://cran.r-project.org/web/packages/fwildclusterboot/news/news.html).
# This warning is displayed once per session.
# ========================================================================
# [WCB CALL] -> boottest_fixest
# ========================================================================
# Parameters:
#   - outcome: log_y
#   - regressors: ['trbin_0_68_3', 'trbin_3_10_6', 'Demand_heat', 'Demand_renewables_and_waste', 'energy_demand_fossil_fuels', 'CPI_growth', 'GDP_per_capita_PPP']
#   - fe: ['unit_id', 'Year']
#   - cluster: ['unit_id']
#   - param: trbin_0_68_3
#   - joint_zero: None
#   - B: 100
#   - type/weights: rademacher
#   - impose_null: True
#   - seed: None
#   - Formula: log_y ~ trbin_0_68_3 + trbin_3_10_6 + Demand_heat + Demand_renewables_and_waste + energy_demand_fossil_fuels + CPI_growth + GDP_per_capita_PPP | unit_id + Year
#
# Note: The bootstrap usually performs best when the confidence
# level (here, 0.95 % times the number of replications plus 1 (
# 100 + 1 = 101 ) is an integer.
# ========================================================================
# [WCB CALL] -> boottest_fixest
# ========================================================================
# Parameters:
#   - outcome: log_y
#   - regressors: ['trbin_0_68_3', 'trbin_3_10_6', 'Demand_heat', 'Demand_renewables_and_waste', 'energy_demand_fossil_fuels', 'CPI_growth', 'GDP_per_capita_PPP']
#   - fe: ['unit_id', 'Year']
#   - cluster: ['unit_id']
#   - param: trbin_3_10_6
#   - joint_zero: None
#   - B: 100
#   - type/weights: rademacher
#   - impose_null: True
#   - seed: None
#   - Formula: log_y ~ trbin_0_68_3 + trbin_3_10_6 + Demand_heat + Demand_renewables_and_waste + energy_demand_fossil_fuels + CPI_growth + GDP_per_capita_PPP | unit_id + Year
#
# Note: The bootstrap usually performs best when the confidence
# level (here, 0.95 % times the number of replications plus 1 (
# 100 + 1 = 101 ) is an integer.
# ========================================================================
# [WCB CALL] -> mboottest_fixest
# ========================================================================
# Parameters:
#   - outcome: log_y
#   - regressors: ['trbin_0_68_3', 'trbin_3_10_6', 'Demand_heat', 'Demand_renewables_and_waste', 'energy_demand_fossil_fuels', 'CPI_growth', 'GDP_per_capita_PPP']
#   - fe: ['unit_id', 'Year']
#   - cluster: ['unit_id']
#   - param: None
#   - joint_zero: ['trbin_0_68_3', 'trbin_3_10_6']
#   - B: 100
#   - type/weights: rademacher
#   - impose_null: True
#   - seed: None
#   - Formula: log_y ~ trbin_0_68_3 + trbin_3_10_6 + Demand_heat + Demand_renewables_and_waste + energy_demand_fossil_fuels + CPI_growth + GDP_per_capita_PPP | unit_id + Year
#
# Too guarantee reproducibility, don't forget to set a global
# random seed via `set.seed()`.
# This message is displayed once every 8 hours.
# R callback write-console: Starting Julia ...
# ========================================================================
# [WCB CALL] -> mboottest_fixest
# ========================================================================
# Parameters:
#   - outcome: log_y
#   - regressors: ['ES_tm5', 'ES_tm4', 'ES_tm3', 'ES_tm2', 'ES_t0', 'ES_t1', 'ES_t2', 'ES_t3', 'ES_t4', 'ES_t5', 'ES_t6', 'ES_t7', 'ES_t8', 'Demand_heat', 'Demand_renewables_and_waste', 'energy_demand_fossil_fuels', 'CPI_growth', 'GDP_per_capita_PPP']
#   - fe: ['unit_id', 'Year']
#   - cluster: ['unit_id']
#   - param: None
#   - joint_zero: ['ES_tm5', 'ES_tm4', 'ES_tm3', 'ES_tm2', 'ES_t0', 'ES_t1', 'ES_t2', 'ES_t3', 'ES_t4', 'ES_t5', 'ES_t6', 'ES_t7', 'ES_t8']
#   - B: 100
#   - type/weights: rademacher
#   - impose_null: True
#   - seed: 123
#   - Formula: log_y ~ ES_tm5 + ES_tm4 + ES_tm3 + ES_tm2 + ES_t0 + ES_t1 + ES_t2 + ES_t3 + ES_t4 + ES_t5 + ES_t6 + ES_t7 + ES_t8 + Demand_heat + Demand_renewables_and_waste + energy_demand_fossil_fuels + CPI_growth + GDP_per_capita_PPP | unit_id + Year
#
# [HonestDiD] Exposure-weighted l_vec: [0.14754098 0.14754098 0.14754098 0.1147541  0.1147541  0.09836066
#  0.08196721 0.08196721 0.06557377]
# ========================================================================
# [HonestDiD CALL] -> createSensitivityResults_relativeMagnitudes
# ========================================================================
# Parameters:
#   - betahat length: 13
#   - Sigma shape: (13, 13)
#   - numPrePeriods: 4
#   - numPostPeriods: 9
#   - Mbar grid: [0.         0.22222222 0.44444444 0.66666667 0.88888889 1.11111111
#  1.33333333 1.55555556 1.77777778 2.        ]
#   - l_vec: [0.14754098 0.14754098 0.14754098 0.1147541  0.1147541  0.09836066
#  0.08196721 0.08196721 0.06557377]
#
# [HonestDiD] failed: name 'sigma' is not defined
# Traceback (most recent call last):
#   File "C:\Users\rjsou\Documents\PhD\did_study\did_study\study.py", line 302, in _run_honest_did
#     res = honest_did_bounds(
#         betas=betas,
#     ...<6 lines>...
#         l_vec=l_vec,
#     )
#   File "C:\Users\rjsou\Documents\PhD\did_study\did_study\robustness\honest_did.py", line 176, in honest_did_bounds
#     raise Exception(sigma)
#                     ^^^^^
# NameError: name 'sigma' is not defined. Did you mean: 'Sigma'?

# %%
results.es_wcb_p
# Out:
# 0.64

# %%
from did_study.reporting.summary import print_and_plot_summary, study_printable_from_didstudy
a = study_printable_from_didstudy(results) 
print_and_plot_summary(a, make_combo=True)
# Out:
# ==============================================================================
# PANEL STATS
# ==============================================================================
# Units: 295 | Ever-treated: 9 | Obs: 11822 | Post rows: 98 (0.8%)
# Bin edges: [0.1, 0.68, 3.0, 10.6]
# [Bin support] units/rows per bin:
#   - [0.1, 0.68): units=4 rows=47
#   - [0.68, 3): units=2 rows=12
#   - [3, 10.6): units=2 rows=29
# Covariate VIFs:
#   - energy_demand_fossil_fuels: 2.17
#   - Demand_renewables_and_waste: 1.83
#   - Demand_heat: 1.34
#   - GDP_per_capita_PPP: 1.04
#   - CPI_growth: 1.01
# ==============================================================================
# ATT^o (pooled)
# ==============================================================================
# coef = -0.191 (SE 0.103, p 0.063) | 95% CI [-0.393, 0.010] | clusters=295, n=11822
# WCB p = <0.001 - (fwildclusterboot::boottest, two-sided; weights=auto, B=100)
# MDE (alpha=0.05, 80% power): 0.2892 (Deltalog scale ~ percentage points; 0.01 ~ 1 p.p.)
# ==============================================================================
# ATT^o by dose bin
# ==============================================================================
#       bin      coef        p  p_wcb  clusters  n_obs  MDE_analytic        lo       hi
# [0.68, 3)  0.098198 0.704089   0.21       2.0   12.0      0.726050 -0.408064 0.604461
# [3, 10.6) -0.391001 0.152608   0.00       2.0   29.0      0.766385 -0.925388 0.143386
#
# ==============================================================================
# ATT^o summary table (pooled + bins)
# ==============================================================================
#     group   coef    se     p          95% CI     WCB p
#    pooled -0.191 0.103 0.063 [-0.393, 0.010] <0.001***
# [0.68, 3)  0.098 0.258 0.704 [-0.408, 0.604]     0.210
# [3, 10.6) -0.391 0.273 0.153 [-0.925, 0.143] <0.001***
#
# ==============================================================================
# Event Study (pooled)
# ==============================================================================
# [first rows]
#  event_time      beta       se        p        lo       hi
#          -5  0.015707 0.097121 0.871518 -0.174650 0.206065
#          -4  0.028364 0.100399 0.777553 -0.168419 0.225146
#          -3 -0.003632 0.106875 0.972888 -0.213107 0.205842
#          -2 -0.014718 0.118669 0.901295 -0.247308 0.217872
#           0 -0.043846 0.135941 0.747047 -0.310291 0.222599
#           1 -0.056797 0.134351 0.672478 -0.320124 0.206530
#           2 -0.041358 0.140934 0.769174 -0.317588 0.234872
#           3 -0.188339 0.113378 0.096683 -0.410561 0.033883
# PTA (leads joint = 0) p = 0.832 - Pre-trend: fail to reject H0 at 5%.
# Event-study support (pooled):
#   Pre rows [-5..-1]: 45 (units 9)
#   Post rows [0..8]: 61 (units 9)
#   Support by bin:
#     - [0.1, 0.68): pre rows=20, post rows=25, units=4
#     - [0.68, 3): pre rows=10, post rows=12, units=2
#     - [3, 10.6): pre rows=10, post rows=15, units=2
#
# ==============================================================================
# HonestDiD
# ==============================================================================
# [first rows]
#  M=0.00: [-0.326, +0.081] (naive theta_hat=-0.123)
#  M=0.22: [-0.512, +0.243] (naive theta_hat=-0.123)
#  M=0.44: [-0.703, +0.404] (naive theta_hat=-0.123)
#  Summary: bounds include 0 across M-grid (no robust sign).
# ==============================================================================
# Overall Support
# ==============================================================================
# PTA (pre-trends): p = 0.832 -> PASS (fail-to-reject is PASS).
# Event-study joint WCB test (all coefficients): p = 0.640
#
# ATT^o (pooled):
#   Estimate: -0.1914 (p = 0.063, WCB p = <0.001***)
#   MDE ratio (|estimate|/MDE): 0.66
#   Actual power @ |estimate|: 45.7%
#   MDE (alpha=0.05, 80% power): 0.2892
#   |estimate| > MDE: No -> Effect may not be robust
#
# ATT^o by bin:
#   [0.68, 3): 0.0982 (p = 0.704, WCB p = 0.210)
#   [3, 10.6): -0.3910 (p = 0.153, WCB p = <0.001***)
#
# WCB omnibus over bins: NA (not computed)
#
# HonestDiD: bounds include 0 across M-grid -> no robust sign.

# %%
b = getattr(results, "honest_did", None)

# %%
b
# Out:
# {'M': array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  ]),
#  'lo': array([-0.17966177, -0.20158573, -0.2235097 , -0.24543367, -0.26735764,
#         -0.28928161, -0.31120557, -0.33312954, -0.35505351]),
#  'hi': array([-0.17966177, -0.1577378 , -0.13581383, -0.11388986, -0.09196589,
#         -0.07004192, -0.04811796, -0.02619399, -0.00427002]),
#  'theta_hat': -0.1796617657222675}

# %%
from did_study.robustness.wcb import wcb_att_pvalue_r
df = results["panel"]
y  = cfg.outcome
covs = results["panel_info"].get("covariates_used", [])
fe = [cfg.year_col] + ([] if y.startswith("d_") else [cfg.unit_cols[0]])
p = wcb_att_pvalue_r(df, outcome=y, regressors=["treated_now"]+covs,
                     fe=fe, cluster=cfg.unit_cols[0], param="treated_now",
                     B=9999, weights="webb", impose_null=True, seed=123)
print("WCB ATT^o p =", p)
from did_study.robustness.wcb import wcb_joint_pvalue_r
# using the same regressors you fit the ES with
pta_p = wcb_joint_pvalue_r(df, outcome=y, regressors=inter_cols+covs,
                           fe=fe, cluster=cfg.unit_cols[0],
                           joint_zero=lead_names,
                           B=9999, weights="webb", impose_null=True, seed=123)
print("PTA WCB p =", pta_p)

# %%
def get_VIF_values(
    df: pd.DataFrame,
    predictors: list,
    min_non_missing: float = 0.50,  # keep cols with ≥50% non-missing
    min_rows: int = 30,             # need rows >> cols
    save_file: str = None
) -> pd.DataFrame:
    X = df[predictors].copy()

    # Screen: coverage & variance
    keep = []
    for c in X.columns:
        s = X[c]
        if s.notna().mean() >= min_non_missing and s.nunique(dropna=True) > 1:
            keep.append(c)
    X = X[keep]

    # Median-impute remaining missings to avoid row wipeout (safer than fillna(0))
    X = X.apply(lambda s: s.fillna(s.median()), axis=0)

    # Bail if not enough data
    if X.shape[1] <= 1 or X.shape[0] < max(min_rows, 2 * X.shape[1]):
        print("[VIF] Skipped: insufficient rows/columns after screening.")
        return pd.DataFrame({"feature": keep, "VIF": np.nan})

    Xc = add_constant(X, has_constant="add")

    rows = []
    for i, col in enumerate(Xc.columns):
        if col == "const":   # do not report VIF for the constant
            continue
        try:
            vif_val = float(variance_inflation_factor(Xc.values, i))
        except Exception:
            vif_val = np.nan
        rows.append({"feature": col, "VIF": vif_val})

    vif_df = (pd.DataFrame(rows)
                .sort_values("VIF", ascending=False)
                .reset_index(drop=True))

    print("\n=== VIF (differenced covariates) ===")
    print(vif_df.head(20).to_string(index=False))

    if save_file:
        try:
            vif_df.to_csv(save_file, index=False)
        except Exception as e:
            print(f"[VIF] Could not save file: {e}")
    return vif_df

# %%
raw_df['a/b'] = ''

# %%
import numpy as np
get_VIF_values(results['att_bins'].used, predictors=d_covs)

# %%
raw_df['eor_capacity'].describe()
